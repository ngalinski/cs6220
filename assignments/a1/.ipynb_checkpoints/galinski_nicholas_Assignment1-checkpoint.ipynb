# %% [markdown]
# # Assignment 1: Exploring the MovieLens Dataset
# #### Extracted (and slightly modified) from Python for Data Analysis (Wes McKinney)
# #### Working off of previously modified and maniupulated [GitHub link](https://github.com/NUOEL/cs6220/blob/master/M01-A01-%20Movie%20Rating.ipynb)

# %% [markdown]
# This dataset contains 1 million ratings collected from 6000 users on 4000 movies, and it is organized into three tables:
# - Ratings
# - Users
# - Movie information
#
# Each table is available as a separate file, each containing a series of rows where columns are separated by ::

# %% [markdown]
# #### Starting code from the link above

# %%
# Imports to be used later
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
unames = ['user_id', 'gender', 'age', 'occupation', 'zip']
users = pd.read_table('ml-1m/users.dat', sep='::', header=None, names=unames, engine='python')

rnames = ['user_id', 'movie_id', 'rating', 'timestamp']
ratings = pd.read_table('ml-1m/ratings.dat', sep='::', header=None, names=rnames, engine='python')

mnames = ['movie_id', 'title', 'genres']
movies = pd.read_table('ml-1m/movies.dat', sep='::', header=None, names=mnames, engine='python')

# %%
users[:5]
# Out:
#    user_id gender  age  occupation    zip
# 0        1      F    1          10  48067
# 1        2      M   56          16  70072
# 2        3      M   25          15  55117
# 3        4      M   45           7  02460
# 4        5      M   25          20  55455

# %%
ratings[:5]
# Out:
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291

# %%
movies[:5]
# Out:
#    movie_id                               title                        genres
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy

# %%
data = pd.merge(pd.merge(ratings, users), movies)
data.head(1)
# Out:
#    user_id  movie_id  rating  timestamp gender  age  occupation    zip  \
# 0        1      1193       5  978300760      F    1          10  48067
#
#                                     title genres
# 0  One Flew Over the Cuckoo's Nest (1975)  Drama

# %%
mean_ratings = data.pivot_table('rating', index='title', columns='gender', aggfunc='mean')
mean_ratings[:5]
# Out:
# gender                                F         M
# title
# $1,000,000 Duck (1971)         3.375000  2.761905
# 'Night Mother (1986)           3.388889  3.352941
# 'Til There Was You (1997)      2.675676  2.733333
# 'burbs, The (1989)             2.793478  2.962085
# ...And Justice for All (1979)  3.828571  3.689024

# %%
ratings_by_title = data.groupby('title').size()
ratings_by_title[:5]
# Out:
# title
# $1,000,000 Duck (1971)            37
# 'Night Mother (1986)              70
# 'Til There Was You (1997)         52
# 'burbs, The (1989)               303
# ...And Justice for All (1979)    199
# dtype: int64

# %%
active_titles = ratings_by_title.index[ratings_by_title >= 250]
active_titles[:5]
# Out:
# Index([''burbs, The (1989)', '10 Things I Hate About You (1999)',
#        '101 Dalmatians (1961)', '101 Dalmatians (1996)',
#        '12 Angry Men (1957)'],
#       dtype='object', name='title')

# %%
mean_ratings = mean_ratings.loc[active_titles]
mean_ratings[:5]
# Out:
# gender                                    F         M
# title
# 'burbs, The (1989)                 2.793478  2.962085
# 10 Things I Hate About You (1999)  3.646552  3.311966
# 101 Dalmatians (1961)              3.791444  3.500000
# 101 Dalmatians (1996)              3.240000  2.911215
# 12 Angry Men (1957)                4.184397  4.328421

# %%
top_female_ratings = mean_ratings.sort_values(by='F', ascending=False)
top_female_ratings[:10]
# Out:
# gender                                                     F         M
# title
# Close Shave, A (1995)                               4.644444  4.473795
# Wrong Trousers, The (1993)                          4.588235  4.478261
# Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)       4.572650  4.464589
# Wallace & Gromit: The Best of Aardman Animation...  4.563107  4.385075
# Schindler's List (1993)                             4.562602  4.491415
# Shawshank Redemption, The (1994)                    4.539075  4.560625
# Grand Day Out, A (1992)                             4.537879  4.293255
# To Kill a Mockingbird (1962)                        4.536667  4.372611
# Creature Comforts (1990)                            4.513889  4.272277
# Usual Suspects, The (1995)                          4.513317  4.518248

# %%
top_male_ratings = mean_ratings.sort_values(by='M', ascending=False)
top_male_ratings[:10]
# Out:
# gender                                                     F         M
# title
# Godfather, The (1972)                               4.314700  4.583333
# Seven Samurai (The Magnificent Seven) (Shichini...  4.481132  4.576628
# Shawshank Redemption, The (1994)                    4.539075  4.560625
# Raiders of the Lost Ark (1981)                      4.332168  4.520597
# Usual Suspects, The (1995)                          4.513317  4.518248
# Star Wars: Episode IV - A New Hope (1977)           4.302937  4.495307
# Schindler's List (1993)                             4.562602  4.491415
# Wrong Trousers, The (1993)                          4.588235  4.478261
# Close Shave, A (1995)                               4.644444  4.473795
# Rear Window (1954)                                  4.484536  4.472991

# %%
mean_ratings['diff'] = mean_ratings['M'] - mean_ratings['F']
sorted_by_diff = mean_ratings.sort_values(by='diff')
sorted_by_diff[:10]
# Out:
# gender                                        F         M      diff
# title
# Dirty Dancing (1987)                   3.790378  2.959596 -0.830782
# Jumpin' Jack Flash (1986)              3.254717  2.578358 -0.676359
# Grease (1978)                          3.975265  3.367041 -0.608224
# Little Women (1994)                    3.870588  3.321739 -0.548849
# Steel Magnolias (1989)                 3.901734  3.365957 -0.535777
# Anastasia (1997)                       3.800000  3.281609 -0.518391
# Rocky Horror Picture Show, The (1975)  3.673016  3.160131 -0.512885
# Color Purple, The (1985)               4.158192  3.659341 -0.498851
# Age of Innocence, The (1993)           3.827068  3.339506 -0.487561
# Free Willy (1993)                      2.921348  2.438776 -0.482573

# %%
sorted_by_diff[::-1][:10]
# Out:
# gender                                         F         M      diff
# title
# Good, The Bad and The Ugly, The (1966)  3.494949  4.221300  0.726351
# Kentucky Fried Movie, The (1977)        2.878788  3.555147  0.676359
# Dumb & Dumber (1994)                    2.697987  3.336595  0.638608
# Longest Day, The (1962)                 3.411765  4.031447  0.619682
# Cable Guy, The (1996)                   2.250000  2.863787  0.613787
# Evil Dead II (Dead By Dawn) (1987)      3.297297  3.909283  0.611985
# Hidden, The (1987)                      3.137931  3.745098  0.607167
# Rocky III (1982)                        2.361702  2.943503  0.581801
# Caddyshack (1980)                       3.396135  3.969737  0.573602
# For a Few Dollars More (1965)           3.409091  3.953795  0.544704

# %% [markdown]
# ### Q1: An aggregate of the movie ratings for each particular genre

# %% [markdown]
# It's important to remember that some movies belong to multiple genres, so they must be split and counted in multiple places. The first step is to split the genres by the pipe. This took some time and playing around with. The second step is to group by genres and then get the averages.

# %%
#genre_ratings = pd.pivot_table(data,index=["genres"], values=["rating"])
genre_ratings = data.set_index(data.columns.drop('genres',1).tolist()).genres.str.split('|', expand=True).stack().reset_index().rename(columns={0:'genres'}).loc[:, data.columns]
genre_ratings
# Out:
#          user_id  movie_id  rating  timestamp gender  age  occupation    zip  \
# 0              1      1193       5  978300760      F    1          10  48067
# 1              2      1193       5  978298413      M   56          16  70072
# 2             12      1193       4  978220179      M   25          12  32793
# 3             15      1193       4  978199279      M   25           7  22903
# 4             17      1193       5  978158471      M   50           1  95350
# ...          ...       ...     ...        ...    ...  ...         ...    ...
# 2101810     5780      2845       1  958153068      M   18          17  92886
# 2101811     5851      3607       5  957756608      F   18          20  55410
# 2101812     5851      3607       5  957756608      F   18          20  55410
# 2101813     5851      3607       5  957756608      F   18          20  55410
# 2101814     5938      2909       4  957273353      M   25           1  35401
#
# ...

# %%
# Average of each genre
# I could not figure out why Drama1 and Drama are not together
avg_genre = genre_ratings.groupby('genres').agg({'rating': [np.mean]})
avg_genre
# Out:
#                rating
#                  mean
# genres
# Action       3.491185
# Adventure    3.477257
# Animation    3.684868
# Children's   3.422035
# Comedy       3.522099
# Crime        3.708679
# Documentary  3.933123
# Drama        3.766407
# Drama1       3.310345
# Fantasy      3.447371
# Film-Noir    4.075188
# Horror       3.215013
# Musical      3.665519
# Mystery      3.668102
# Romance      3.607465
# Sci-Fi       3.466521
# Thriller     3.570466
# War          3.893327
# Western      3.637770

# %% [markdown]
# ### Q2: The top five highest rated genres by women

# %%
# use the already de-piped data from above
genres = genre_ratings.pivot_table('rating', index='genres', columns='gender', aggfunc='mean')
genres[:10]
# Out:
# gender              F         M
# genres
# Action       3.490252  3.491386
# Adventure    3.512879  3.468125
# Animation    3.744702  3.661335
# Children's   3.572548  3.358961
# Comedy       3.571938  3.503667
# Crime        3.689332  3.713720
# Documentary  3.946392  3.928811
# Drama        3.765721  3.766669
# Drama1       3.500000  3.194444
# Fantasy      3.513076  3.426603

# %%
# Five top female genres
top_female_genre = genres['F'].sort_values(ascending=False)
top_female_genre[:5]
# Out:
# genres
# Film-Noir      4.018087
# Documentary    3.946392
# War            3.893138
# Musical        3.809108
# Drama          3.765721
# Name: F, dtype: float64

# %% [markdown]
# ### Q3: The top five highest rated genres by men

# %%
# using the same genres sorted data as above
top_male_genre = genres['M'].sort_values(ascending=False)
top_male_genre[:5]
# Out:
# genres
# Film-Noir      4.092254
# Documentary    3.928811
# War            3.893375
# Drama          3.766669
# Crime          3.713720
# Name: M, dtype: float64

# %% [markdown]
# ### Q4: The Lion King (1994), broken down by age ranges

# %% [markdown]
# There are multiple parts in this one:
# - Categorize the existing age groups and combine them
# - Get specific information about The Lion King

# %%
# Take the age ranges given in the files and change it to age groups
age_range = data.age.unique()
age_range.sort()
age_groups = {
    1: 'Under 18', 
    18: 'Under 18', 
    25: '19 to 45', 
    35: '19 to 45', 
    45: '19 to 45', 
    50: 'Above 45',
    56: 'Above 45'
}

data['age_group'] = [age_groups[x] for x in data['age']]
data[:10]
# Out:
#    user_id  movie_id  rating  timestamp gender  age  occupation    zip  \
# 0        1      1193       5  978300760      F    1          10  48067
# 1        2      1193       5  978298413      M   56          16  70072
# 2       12      1193       4  978220179      M   25          12  32793
# 3       15      1193       4  978199279      M   25           7  22903
# 4       17      1193       5  978158471      M   50           1  95350
# 5       18      1193       4  978156168      F   18           3  95825
# 6       19      1193       5  982730936      M    1          10  48073
# 7       24      1193       5  978136709      F   25           7  10023
# 8       28      1193       3  978125194      F   25           1  14607
# 9       33      1193       5  978557765      M   45           3  55421
#
#                                     title genres age_group
# 0  One Flew Over the Cuckoo's Nest (1975)  Drama  Under 18
# 1  One Flew Over the Cuckoo's Nest (1975)  Drama  Above 45
# ...

# %%
# Find the Lion King in the data
movie = data[data.title == "Lion King, The (1994)"]
age_ratings = movie.pivot_table('rating', index='age_group', columns='title', fill_value=0)
age_ratings
# Out:
# title      Lion King, The (1994)
# age_group
# 19 to 45                3.861472
# Above 45                3.896104
# Under 18                3.851852

# %% [markdown]
# ### Q5: A function that takes in a user_id and a movie_id, and returns a list of other user_id that rated the movie_id the same rating

# %%
# I couldn't find a better way to make this data look and still be compact
# Find the users that rate the Lion King the same as user 6 (users 1-5 do not have ratings for this movie)
def users_with_same_ratings(user, movie):    
    user_rating = data[data['user_id'] == user]
    movie_data = user_rating[user_rating['movie_id'] == movie]
    movie_rating = movie_data.loc[movie_data.index[0], 'rating']
    comp = data[data['movie_id'] == movie]
    users_list = list(comp.user_id[comp['rating'] == movie_rating])
    users_list.remove(user)
    return users_list
print(users_with_same_ratings(6,364))
# Out:
# [10, 15, 24, 38, 49, 53, 75, 80, 86, 99, 109, 112, 139, 150, 163, 169, 187, 204, 225, 271, 272, 273, 324, 333, 392, 424, 438, 450, 509, 516, 528, 531, 544, 551, 555, 614, 629, 635, 637, 639, 664, 669, 678, 690, 712, 715, 716, 720, 721, 727, 735, 749, 753, 775, 783, 800, 802, 807, 822, 839, 854, 866, 891, 911, 924, 931, 936, 959, 963, 998, 1001, 1004, 1032, 1042, 1050, 1057, 1087, 1088, 1092, 1112, 1117, 1137, 1158, 1187, 1227, 1239, 1246, 1266, 1271, 1272, 1291, 1311, 1312, 1317, 1322, 1325, 1348, 1390, 1393, 1399, 1451, 1465, 1494, 1495, 1542, 1546, 1553, 1587, 1591, 1605, 1635, 1650, 1671, 1680, 1688, 1698, 1737, 1752, 1757, 1758, 1759, 1800, 1806, 1812, 1817, 1824, 1828, 1833, 1836, 1880, 1883, 1903, 1904, 1920, 1926, 1941, 1950, 1954, 1956, 1987, 2000, 2010, 2012, 2015, 2016, 2018, 2047, 2097, 2100, 2109, 2116, 2125, 2136, 2180, 2214, 2222, 2223, 2225, 2232, 2255, 2258, 2266, 2290, 2303, 2334, 2340, 2343, 2350, 2351, 2383, 2384, 2389, 2454, 2457, 2459, 2489, 2496, 2507, 2519, 252
# ...

# %% [markdown]
# ### Q6: Some other statistic, figure, aggregate, or plot that you created using this dataset, along with a short description of what interesting observations you derived from it

# %%
# A summary of the musical genre
musicals = genre_ratings[genre_ratings.genres == "Musical"]
musicals
# Out:
#          user_id  movie_id  rating   timestamp gender  age  occupation    zip  \
# 1727           1       661       3   978302109      F    1          10  48067
# 1730          23       661       2   978460739      M   35           0  90049
# 1733          49       661       3   977972750      M   18          12  77084
# 1736          53       661       5   977979726      M   25           0  96931
# 1739          57       661       4   977935511      M   18          19  30350
# ...          ...       ...     ...         ...    ...  ...         ...    ...
# 2101684     3610      2213       1   974824749      M   18           6  30064
# 2101686     3610      2217       1   974824774      M   18           6  30064
# 2101689     3610       975       1   974824749      M   18           6  30064
# 2101691     5045       975       2   962502840      M   35           0  43081
# 2101753     4579      3315       2  1033002064      F   18           4  63332
#
# ...

# %%
# A summary of the animation genre
animation = genre_ratings[genre_ratings.genres == "Animation"]
animation
# Out:
#          user_id  movie_id  rating  timestamp gender  age  occupation    zip  \
# 1725           1       661       3  978302109      F    1          10  48067
# 1728          23       661       2  978460739      M   35           0  90049
# 1731          49       661       3  977972750      M   18          12  77084
# 1734          53       661       5  977979726      M   25           0  96931
# 1737          57       661       4  977935511      M   18          19  30350
# ...          ...       ...     ...        ...    ...  ...         ...    ...
# 2098752     4685      1151       4  963643510      M   35           1  55454
# 2098755     5039      1151       1  962512674      F   35           4  97068
# 2098758     5265      1151       5  961221962      M   45           1  97405
# 2098761     5468      1151       4  967156474      M   25          12  94618
# 2098764     5686      1151       2  958690369      M   56          16  60610
#
# ...

# %%
# a summary of the children's genre
child = genre_ratings[genre_ratings.genres == "Children's"]
child
# Out:
#          user_id  movie_id  rating  timestamp gender  age  occupation     zip  \
# 1726           1       661       3  978302109      F    1          10   48067
# 1729          23       661       2  978460739      M   35           0   90049
# 1732          49       661       3  977972750      M   18          12   77084
# 1735          53       661       5  977979726      M   25           0   96931
# 1738          57       661       4  977935511      M   18          19   30350
# ...          ...       ...     ...        ...    ...  ...         ...     ...
# 2099581     4150      1426       2  965344367      M   25           0   29672
# 2099582     5558      1426       1  959391682      M    1          10   02446
# 2099583     5698      1426       2  958595285      M   35          14   55418
# 2101520     2106      2039       1  974756684      F   18          20  495321
# 2101801     5420      1843       3  960156505      F    1          19   14850
#
# ...

# %%
# Copied age range code from above
age_range = genre_ratings.age.unique()
age_range.sort()
age_groups = {
    1: 'Under 18', 
    18: 'Under 18', 
    25: '19 to 45', 
    35: '19 to 45', 
    45: '19 to 45', 
    50: 'Above 45',
    56: 'Above 45'
}

genre_ratings['age_group'] = [age_groups[x] for x in genre_ratings['age']]
genre_ratings[:10]
# Out:
#    user_id  movie_id  rating  timestamp gender  age  occupation    zip  \
# 0        1      1193       5  978300760      F    1          10  48067
# 1        2      1193       5  978298413      M   56          16  70072
# 2       12      1193       4  978220179      M   25          12  32793
# 3       15      1193       4  978199279      M   25           7  22903
# 4       17      1193       5  978158471      M   50           1  95350
# 5       18      1193       4  978156168      F   18           3  95825
# 6       19      1193       5  982730936      M    1          10  48073
# 7       24      1193       5  978136709      F   25           7  10023
# 8       28      1193       3  978125194      F   25           1  14607
# 9       33      1193       5  978557765      M   45           3  55421
#
#                                     title genres age_group
# 0  One Flew Over the Cuckoo's Nest (1975)  Drama  Under 18
# 1  One Flew Over the Cuckoo's Nest (1975)  Drama  Above 45
# ...

# %%
# look at each movie in the musical genre by age group
sorted_musicals = genre_ratings[genre_ratings.genres == "Musical"].groupby(['title','age_group'])
mus_averages = sorted_musicals.agg({'rating': [np.size, np.mean]})
mus_averages[:50]
# Out:
#                                           rating
#                                             size      mean
# title                           age_group
# Aladdin (1992)                  19 to 45     837  3.847073
#                                 Above 45      83  3.493976
#                                 Under 18     431  3.730858
# Alice in Wonderland (1951)      19 to 45     295  3.681356
#                                 Above 45      50  3.960000
#                                 Under 18     180  3.650000
# All Dogs Go to Heaven 2 (1996)  19 to 45      45  1.955556
#                                 Above 45       5  3.600000
#                                 Under 18      25  2.000000
# All That Jazz (1979)            19 to 45     234  3.794872
#                                 Above 45      67  4.074627
#                                 Under 18      16  3.187500
# American Pop (1981)             19 to 45      90  2.966667
# ...

# %%
# animation genre by age group
sorted_animation = genre_ratings[genre_ratings.genres == "Animation"].groupby(['title','age_group'])
averages_ani = sorted_animation.agg({'rating': [np.size, np.mean]})
averages_ani[:50]
# Out:
#                                                          rating
#                                                            size      mean
# title                                          age_group
# 101 Dalmatians (1961)                          19 to 45     347  3.729107
#                                                Above 45      61  3.491803
#                                                Under 18     157  3.343949
# Adventures of Rocky and Bullwinkle, The (2000) 19 to 45     130  2.407692
#                                                Above 45      17  3.235294
#                                                Under 18      59  2.474576
# Akira (1988)                                   19 to 45     299  3.892977
#                                                Above 45      18  3.611111
#                                                Under 18     135  4.066667
# Aladdin (1992)                                 19 to 45     837  3.847073
# ...

# %%
# children's genre by age group
sorted_child = genre_ratings[genre_ratings.genres == "Children's"].groupby(['title','age_group'])
averages_child = sorted_child.agg({'rating': [np.size, np.mean]})
averages_child[:50]
# Out:
#                                                          rating
#                                                            size      mean
# title                                          age_group
# $1,000,000 Duck (1971)                         19 to 45      27  3.074074
#                                                Above 45       4  2.750000
#                                                Under 18       6  3.000000
# 101 Dalmatians (1961)                          19 to 45     347  3.729107
#                                                Above 45      61  3.491803
#                                                Under 18     157  3.343949
# 101 Dalmatians (1996)                          19 to 45     234  3.136752
#                                                Above 45      34  3.441176
#                                                Under 18      96  2.687500
# 20,000 Leagues Under the Sea (1954)            19 to 45     366  3.707650
# ...

# %% [markdown]
# At first, I thought I would look at the differences in age groups in specific movies that are older or animated and see how they compare (above). I could not find anything useful, so then I turned towards age group and genre average ratings (below).

# %%
# every genre by age group average
aged_genres = genre_ratings.pivot_table('rating', index='genres', columns='age_group', aggfunc='mean')
aged_genres[:10]
# Out:
# age_group    19 to 45  Above 45  Under 18
# genres
# Action       3.486032  3.611131  3.453967
# Adventure    3.474765  3.635071  3.413990
# Animation    3.716387  3.771750  3.595534
# Children's   3.467318  3.577882  3.283524
# Comedy       3.522780  3.648259  3.465517
# Crime        3.702944  3.818342  3.672250
# Documentary  3.951054  3.925153  3.851363
# Drama        3.750777  3.898882  3.730224
# Drama1       3.224490  3.666667  4.000000
# Fantasy      3.470176  3.566504  3.348457

# %%
# the top five genres of the young people
top_under18 = aged_genres['Under 18'].sort_values(ascending=False)
top_under18[:5]
# Out:
# genres
# Film-Noir      4.016092
# Drama1         4.000000
# War            3.858497
# Documentary    3.851363
# Drama          3.730224
# Name: Under 18, dtype: float64

# %%
# the top five genres of the middle aged
top_midage = aged_genres['19 to 45'].sort_values(ascending=False)
top_midage[:5]
# Out:
# genres
# Film-Noir      4.067679
# Documentary    3.951054
# War            3.877376
# Drama          3.750777
# Animation      3.716387
# Name: 19 to 45, dtype: float64

# %%
# the top five genres of the older 
top_above45 = aged_genres['Above 45'].sort_values(ascending=False)
top_above45[:5]
# Out:
# genres
# Film-Noir      4.155996
# War            4.009020
# Documentary    3.925153
# Drama          3.898882
# Mystery        3.887595
# Name: Above 45, dtype: float64

# %% [markdown]
# As noted above, the top genre for all three age groups is Film-Noir. War, Documentary, and Drama all appear in all 3 as well.

# %%
# Graph the average genre ratings
labels = ['Under 18', '19 to 45', 'Above 45']
plt.figure()
ax = aged_genres[labels[:6]].plot(kind='bar', title ="Age Difference",figsize=(30,20),legend=True, fontsize=12)
ax.set_xlabel("Genre",fontsize=12)
ax.set_ylabel("Rating",fontsize=12)
plt.show()

# %% [markdown]
# For the most part, the genres are very close in average rating. The only exception is Drama1 which I think is a fluke because it does not fit in.

# %% [markdown]
# Across the board, those in the age group Above 45 rate movies the highest. This includes Children's, where I assumed it would be the opposite. The middle age group rates movies in the middle for the majority of genres while the youngest group rates movies the lowest.
